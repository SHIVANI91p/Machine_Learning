# %%
#Import Libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer  #    SimpleImputer fill NA values for multiple columns
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder#for encoding purpose use for encoding independet feature/column working same as OHE
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aishwaryamate/Datasets/main/cars.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# ...

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df['normalized-losses'].value_counts()
# Out:
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 106     4
# 93      4
# 118     4
# 148     4
# 122     4
# 83      3
# 125     3
# 154     3
# 115     3
# 137     3
# 101     3
# 119     2
# 87      2
# 89      2
# 192     2
# 197     2
# 158     2
# 81      2
# 188     2
# 194     2
# 153     2
# 129     2
# 108     2
# 110     2
# 164     2
# 145     2
# 113     2
# 256     1
# 107     1
# 90      1
# 231     1
# 142     1
# 121     1
# 78      1
# 98      1
# 186     1
# 77      1
# Name: normalized-losses, dtype: int64

# %%
df[df['horsepower']=='?']
# Out:
#      symboling normalized-losses     make fuel-type body-style drive-wheels  \
# 130          0                 ?  renault       gas      wagon          fwd
# 131          2                 ?  renault       gas  hatchback          fwd
#
#     engine-location  width  height engine-type  engine-size horsepower  \
# 130           front   66.5    55.2         ohc          132          ?
# 131           front   66.6    50.5         ohc          132          ?
#
#      city-mpg  highway-mpg  price
# 130        23           31   9295
# 131        23           31   9895

# %%
df.replace('?', np.nan, inplace=True)   # np.nan replace ? with NA values

# %%
df.isna().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# body-style            0
# drive-wheels          0
# engine-location       0
# width                 0
# height                0
# engine-type           0
# engine-size           0
# horsepower            2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3               NaN  alfa-romero       gas  convertible
# 1            3               NaN  alfa-romero       gas  convertible
# 2            1               NaN  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df['normalized-losses']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      164
# 4      164
#       ...
# 200     95
# 201     95
# 202     95
# 203     95
# 204     95
# Name: normalized-losses, Length: 205, dtype: object

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# body-style            object
# drive-wheels          object
# engine-location       object
# width                float64
# height               float64
# engine-type           object
# engine-size            int64
# horsepower            object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
si = SimpleImputer(strategy='median')

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3               NaN  alfa-romero       gas  convertible
# 1            3               NaN  alfa-romero       gas  convertible
# 2            1               NaN  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df.iloc[:,[1,11]]
# Out:
#     normalized-losses horsepower
# 0                 NaN        111
# 1                 NaN        111
# 2                 NaN        154
# 3                 164        102
# 4                 164        115
# ..                ...        ...
# 200                95        114
# 201                95        160
# 202                95        134
# 203                95        106
# 204                95        114
#
# [205 rows x 2 columns]

# %%
df[['normalized-losses','horsepower']]
# Out:
#     normalized-losses horsepower
# 0                 NaN        111
# 1                 NaN        111
# 2                 NaN        154
# 3                 164        102
# 4                 164        115
# ..                ...        ...
# 200                95        114
# 201                95        160
# 202                95        134
# 203                95        106
# 204                95        114
#
# [205 rows x 2 columns]

# %%
df.loc[:,['normalized-losses','horsepower']]
# Out:
#     normalized-losses horsepower
# 0                 NaN        111
# 1                 NaN        111
# 2                 NaN        154
# 3                 164        102
# 4                 164        115
# ..                ...        ...
# 200                95        114
# 201                95        160
# 202                95        134
# 203                95        106
# 204                95        114
#
# [205 rows x 2 columns]

# %%
df.iloc[:,[1,11]]  = si.fit_transform(df.iloc[:,[1,11]])

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.select_dtypes([int,float])
# Out:
#      symboling  normalized-losses  width  height  engine-size  horsepower  \
# 0            3              115.0   64.1    48.8          130       111.0
# 1            3              115.0   64.1    48.8          130       111.0
# 2            1              115.0   65.5    52.4          152       154.0
# 3            2              164.0   66.2    54.3          109       102.0
# 4            2              164.0   66.4    54.3          136       115.0
# ..         ...                ...    ...     ...          ...         ...
# 200         -1               95.0   68.9    55.5          141       114.0
# 201         -1               95.0   68.8    55.5          141       160.0
# 202         -1               95.0   68.9    55.5          173       134.0
# 203         -1               95.0   68.9    55.5          145       106.0
# 204         -1               95.0   68.9    55.5          141       114.0
#
#      city-mpg  highway-mpg  price
# 0          21           27  13495
# ...

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3              115.0  alfa-romero       gas  convertible
# 1            3              115.0  alfa-romero       gas  convertible
# 2            1              115.0  alfa-romero       gas    hatchback
# 3            2              164.0         audi       gas        sedan
# 4            2              164.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1               95.0        volvo       gas        sedan
# 201         -1               95.0        volvo       gas        sedan
# 202         -1               95.0        volvo       gas        sedan
# 203         -1               95.0        volvo    diesel        sedan
# 204         -1               95.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %% [markdown]
# # Encoding

# %%
#Selecting only categorical columns

# %%
df.select_dtypes(object).columns
# Out:
# Index(['make', 'fuel-type', 'body-style', 'drive-wheels', 'engine-location',
#        'engine-type'],
#       dtype='object')

# %%
cat_cols = df.select_dtypes(object).columns
cat_cols
# Out:
# Index(['make', 'fuel-type', 'body-style', 'drive-wheels', 'engine-location',
#        'engine-type'],
#       dtype='object')

# %%
df[cat_cols]
# Out:
#             make fuel-type   body-style drive-wheels engine-location  \
# 0    alfa-romero       gas  convertible          rwd           front
# 1    alfa-romero       gas  convertible          rwd           front
# 2    alfa-romero       gas    hatchback          rwd           front
# 3           audi       gas        sedan          fwd           front
# 4           audi       gas        sedan          4wd           front
# ..           ...       ...          ...          ...             ...
# 200        volvo       gas        sedan          rwd           front
# 201        volvo       gas        sedan          rwd           front
# 202        volvo       gas        sedan          rwd           front
# 203        volvo    diesel        sedan          rwd           front
# 204        volvo       gas        sedan          rwd           front
#
#     engine-type
# 0          dohc
# 1          dohc
# 2          ohcv
# 3           ohc
# 4           ohc
# ..          ...
# ...

# %%
oe = OrdinalEncoder()

df[cat_cols] = oe.fit_transform(df[cat_cols])

# %%
df
# Out:
#      symboling  normalized-losses  make  fuel-type  body-style  drive-wheels  \
# 0            3              115.0   0.0        1.0         0.0           2.0
# 1            3              115.0   0.0        1.0         0.0           2.0
# 2            1              115.0   0.0        1.0         2.0           2.0
# 3            2              164.0   1.0        1.0         3.0           1.0
# 4            2              164.0   1.0        1.0         3.0           0.0
# ..         ...                ...   ...        ...         ...           ...
# 200         -1               95.0  21.0        1.0         3.0           2.0
# 201         -1               95.0  21.0        1.0         3.0           2.0
# 202         -1               95.0  21.0        1.0         3.0           2.0
# 203         -1               95.0  21.0        0.0         3.0           2.0
# 204         -1               95.0  21.0        1.0         3.0           2.0
#
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                 float64
# fuel-type            float64
# body-style           float64
# drive-wheels         float64
# engine-location      float64
# width                float64
# height               float64
# engine-type          float64
# engine-size            int64
# horsepower           float64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %% [markdown]
# # Model building

# %%
x = df.iloc[:,:-1]
y = df['price']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3, random_state=1)

# %%
lr = LinearRegression()
lr.fit(xtrain,ytrain)
ypred = lr.predict(xtest)
ypred
# Out:
# array([ 6114.11943789,  6899.1299745 ,  5179.12129606,  6534.49022809,
#         9125.91144455, 26384.12259969,  7406.15558344,   895.58275157,
#         5172.9291232 , 13513.24663171, 15407.85345859, 14421.55136235,
#        16418.89788598, 11145.35574554, 16463.66533212, 13896.61774947,
#         7335.98228673,  8845.0632645 , 10862.74899523,  7555.18709439,
#        11006.99145217,  6830.04912601, 13638.73999814,  6363.9621527 ,
#        13732.90563984,  8845.0632645 , 15040.20874209,  6544.19455256,
#         4706.60204753,  9314.78618354,  8128.3940468 , 14321.0634702 ,
#        25655.82279003, 11987.68138692, 19723.90650907,  6557.53154026,
#         8154.91470876, 30658.97297566,  9834.8439003 , 16923.44920496,
#         6520.66900847, 20194.14945986,  7692.55861481,  8459.52258636,
#         8670.04245903,  7166.21791784, 40486.41308962,  7569.40057796,
#        17170.51789287, 18954.92930717, 26190.76513016, 16914.80136249,
# ...

# %%
lr.intercept_ # incercept(c)
# Out:
# -64935.11357978258

# %%
lr.coef_  # slop/weight (m)
# Out:
# array([ 5.71727164e+01,  4.76320989e-01, -2.01309566e+02, -6.22705136e+02,
#        -1.63712110e+02,  1.88863899e+03,  1.63884484e+04,  7.90632094e+02,
#         3.61221503e+02,  2.81207534e+02,  9.82290864e+01, -1.06474945e+01,
#         3.08435166e+02, -4.17126915e+02])

# %%
lr.score(xtrain,ytrain), lr.score(xtest,ytest)  # Accuracy
# Out:
# (0.8504229026078214, 0.7964854785429526)

# %% [markdown]
# # Lasso

# %%
l1 = Lasso()
l1.fit(xtrain,ytrain)
l1.score(xtrain,ytrain), l1.score(xtest,ytest)
# Out:
# (0.8504215478243033, 0.796661521157569)

# %%
l1.coef_
# Out:
# array([ 5.70766693e+01,  4.67141700e-01, -2.01139953e+02, -6.14206970e+02,
#        -1.64751649e+02,  1.88558824e+03,  1.63181959e+04,  7.88680118e+02,
#         3.61783500e+02,  2.81248690e+02,  9.83193653e+01, -1.05310631e+01,
#         3.07274772e+02, -4.15725804e+02])

# %% [markdown]
# # Hyperparameter Tuning

# %%
for i in range(100,200):
    l1 = Lasso(alpha=i)
    l1.fit(xtrain,ytrain)
    print(f"Alpha: {i} Train : {l1.score(xtrain,ytrain)} Test: {l1.score(xtest,ytest)}")
# Out:
# Alpha: 100 Train : 0.8372483974026498 Test: 0.8092040910955611
# Alpha: 101 Train : 0.836989922954141 Test: 0.8092979610738258
# Alpha: 102 Train : 0.8367288785613758 Test: 0.8093910017461712
# Alpha: 103 Train : 0.8364651676681871 Test: 0.8094832684251523
# Alpha: 104 Train : 0.8361989818307349 Test: 0.8095746503624814
# Alpha: 105 Train : 0.8359302253870347 Test: 0.8096652035299016
# Alpha: 106 Train : 0.8356588978359675 Test: 0.8097549282309099
# Alpha: 107 Train : 0.8353849991129143 Test: 0.8098438245155563
# Alpha: 108 Train : 0.8351084257059387 Test: 0.8099319454841271
# Alpha: 109 Train : 0.8348293842179737 Test: 0.810019184028544
# Alpha: 110 Train : 0.8345477714936766 Test: 0.8101055942385991
# Alpha: 111 Train : 0.8342635877040371 Test: 0.8101911760417997
# Alpha: 112 Train : 0.8339767222137542 Test: 0.810275981362897
# Alpha: 113 Train : 0.8336873954613209 Test: 0.8103599056262563
# Alpha: 114 Train : 0.8333954973355284 Test: 0.810443001666504
# ...

# %%
l1 = Lasso(alpha=175)
l1.fit(xtrain,ytrain)
l1.score(xtrain,ytrain), l1.score(xtest,ytest)
# Out:
# (0.8107234361496891, 0.8139459609474126)

# %%
l1.coef_    # so there are two columns which we can remove so this is calles feature selection
# Out:
# array([  26.15091464,   -0.        , -173.02547787,   -0.        ,
#        -363.80743898, 1247.84193718, 3867.709301  ,  391.04314711,
#         451.57194036,  297.35122938,  113.32977728,   11.00742675,
#          70.90090498, -160.35202828])

# %%
xtrain.columns  # so we can remove  normalized-losses,fuel-type or else these columns are no that much important
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'body-style',
#        'drive-wheels', 'engine-location', 'width', 'height', 'engine-type',
#        'engine-size', 'horsepower', 'city-mpg', 'highway-mpg'],
#       dtype='object')

# %% [markdown]
# # Ridge

# %%
l2 = Ridge()

l2.fit(xtrain,ytrain)
l2.score(xtrain,ytrain), l2.score(xtest,ytest)
# Out:
# (0.8435840853399224, 0.8075632224690538)

# %%
for i in range(1,100):
    l2 = Ridge(alpha=i)
    l2.fit(xtrain,ytrain)
    print(f"Alpha: {i} Train: {l2.score(xtrain,ytrain)} Test: {l2.score(xtest,ytest)}")
# Out:
# Alpha: 1 Train: 0.8435840853399224 Test: 0.8075632224690538
# Alpha: 2 Train: 0.8356695734845092 Test: 0.8112192014374258
# Alpha: 3 Train: 0.8296379623431074 Test: 0.8129299663310144
# Alpha: 4 Train: 0.8250699092246865 Test: 0.8138839096972439
# Alpha: 5 Train: 0.8215093087765017 Test: 0.8144682684596017
# Alpha: 6 Train: 0.8186486103834849 Test: 0.8148435627265231
# Alpha: 7 Train: 0.8162882573020809 Test: 0.8150880725612085
# Alpha: 8 Train: 0.8142964263180523 Test: 0.8152447305071581
# Alpha: 9 Train: 0.8125835227290971 Test: 0.8153392574436445
# Alpha: 10 Train: 0.8110868722186455 Test: 0.8153881483263246
# Alpha: 11 Train: 0.8097614513602518 Test: 0.815402561027951
# Alpha: 12 Train: 0.8085741366835053 Test: 0.8153903693701573
# Alpha: 13 Train: 0.8075000372738096 Test: 0.8153573212892012
# Alpha: 14 Train: 0.8065200924084591 Test: 0.8153077294072231
# Alpha: 15 Train: 0.8056194580416448 Test: 0.8152449025615437
# Alpha: 16 Train: 0.804786398073303 Test: 0.8151714264843273
# ...

# %%
l2 = Ridge(alpha=7)   # within less aplha value we got better accuracy so we can select ridge algorithm
l2.fit(xtrain,ytrain)
l2.score(xtrain,ytrain),l2.score(xtest,ytest)
# Out:
# (0.8162882573020809, 0.8150880725612085)

# %%
#l2.coef_
# Out:
# array([ 2.31139279e+02, -3.29204695e+00, -1.90126861e+02, -1.01249352e+03,
#        -6.04047656e+02,  1.71736131e+03,  3.40160377e+03,  3.91530395e+02,
#         5.57861287e+02,  5.13867686e+02,  1.02968876e+02,  2.01227011e+01,
#         2.13425523e+02, -2.79915768e+02])

# %% [markdown]
# # Elastic Net

# %%
en = ElasticNet(alpha=1)
en.fit(xtrain,ytrain)
en.score(xtrain,ytrain), en.score(xtest,ytest)
# Out:
# (0.7866253599240464, 0.8098264817256127)

# %%
#for i in range(1,100):
#    l3=ElasticNet (alpha=i)
#    l3.fit(xtrain,ytrain)
#    print(f"Alpha: {i} Train: {l3.score(xtrain,ytrain)} Test: {l3.score(xtest,ytest)}")
# Out:
# Alpha: 1 Train: 0.7866253599240464 Test: 0.8098264817256127
# Alpha: 2 Train: 0.7785982256935363 Test: 0.8060357239149383
# Alpha: 3 Train: 0.7741098728697711 Test: 0.8038330303232794
# Alpha: 4 Train: 0.7710450291333583 Test: 0.8023305288839749
# Alpha: 5 Train: 0.7687371063143833 Test: 0.8012075675535995
# Alpha: 6 Train: 0.7668931957678061 Test: 0.8003179782274954
# Alpha: 7 Train: 0.7653604622717018 Test: 0.7995845026702189
# Alpha: 8 Train: 0.7640627321201632 Test: 0.7989624987950101
# Alpha: 9 Train: 0.7629190144346731 Test: 0.7984234467905051
# Alpha: 10 Train: 0.7619040267638404 Test: 0.7979480911193563
# Alpha: 11 Train: 0.7609920588765116 Test: 0.7975254942341772
# Alpha: 12 Train: 0.7601634437226541 Test: 0.7971420542460247
# Alpha: 13 Train: 0.7594043321097714 Test: 0.7967925427385447
# Alpha: 14 Train: 0.7587038337680176 Test: 0.7964714888960548
# Alpha: 15 Train: 0.7580533960505055 Test: 0.7961745605956967
# Alpha: 16 Train: 0.7574456236748974 Test: 0.7958954634672686
# ...

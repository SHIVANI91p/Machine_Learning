# %% [markdown]
# # C 5.0

# %%
#Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (10,10)
plt.rcParams['figure.dpi'] = 500
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('C://Users//pawar//Data science//Csv_files//Iris.csv', 
                 index_col=0)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
x = df.iloc[:,:-1]
y = df['Species']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2, random_state=1)

# %%
xtrain.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Id
# 92             6.1           3.0            4.6           1.4
# 136            7.7           3.0            6.1           2.3
# 70             5.6           2.5            3.9           1.1
# 129            6.4           2.8            5.6           2.1
# 115            5.8           2.8            5.1           2.4

# %%
ytrain
# Out:
# Id
# 92     Iris-versicolor
# 136     Iris-virginica
# 70     Iris-versicolor
# 129     Iris-virginica
# 115     Iris-virginica
#             ...
# 134     Iris-virginica
# 138     Iris-virginica
# 73     Iris-versicolor
# 141     Iris-virginica
# 38         Iris-setosa
# Name: Species, Length: 120, dtype: object

# %%
xtest.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Id
# 15             5.8           4.0            1.2           0.2
# 99             5.1           2.5            3.0           1.1
# 76             6.6           3.0            4.4           1.4
# 17             5.4           3.9            1.3           0.4
# 132            7.9           3.8            6.4           2.0

# %%
ytest
# Out:
# Id
# 15         Iris-setosa
# 99     Iris-versicolor
# 76     Iris-versicolor
# 17         Iris-setosa
# 132     Iris-virginica
# 57     Iris-versicolor
# 142     Iris-virginica
# 45         Iris-setosa
# 30         Iris-setosa
# 121     Iris-virginica
# 95     Iris-versicolor
# 6          Iris-setosa
# 103     Iris-virginica
# 52     Iris-versicolor
# 79     Iris-versicolor
# 43         Iris-setosa
# 93     Iris-versicolor
# 67     Iris-versicolor
# 32         Iris-setosa
# 36         Iris-setosa
# 91     Iris-versicolor
# 85     Iris-versicolor
# 78     Iris-versicolor
# 41         Iris-setosa
# 126     Iris-virginica
# 100    Iris-versicolor
# 34         Iris-setosa
# 20         Iris-setosa
# 74     Iris-versicolor
# 147     Iris-virginica
# Name: Species, dtype: object

# %% [markdown]
# ## Model  Building

# %%
dt = DecisionTreeClassifier(criterion='entropy')

dt.fit(xtrain,ytrain)
ypred = dt.predict(xtest)
ypred
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
x.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %%
dt.feature_importances_         # Information Gain (IG)
# Out:
# array([0.00848378, 0.02764493, 0.09849491, 0.86537637])

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(ytest,ypred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30

# %%
confusion_matrix(ytest,ypred)
# Out:
# array([[11,  0,  0],
#        [ 0, 12,  1],
#        [ 0,  0,  6]], dtype=int64)

# %%
#from sklearn.metrics import accuracy_score

# %%
#accuracy_score(ytest,ypred)

# %%
print('Training accuracy: ', dt.score(xtrain,ytrain))   # it is generalized model
print('Testing Accuracy: ', dt.score(xtest,ytest))
# Out:
# Training accuracy:  1.0
# Testing Accuracy:  0.9666666666666667

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
x.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %%
dt
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
tree.plot_tree(dt, feature_names= ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'],
              class_names=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'],max_depth=2, 
              filled=True)
plt.show()

# %%
dt.feature_importances_ #It returns information gain of all columns
# Out:
# array([0.00848378, 0.02764493, 0.09849491, 0.86537637])

# %%
x.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %% [markdown]
# # CART

# %% [markdown]
# <code>CLASSIFICATION</CODE>

# %%
dtc = DecisionTreeClassifier(criterion='gini')

# %%
dtc.fit(xtrain,ytrain)
ypred = dtc.predict(xtest)

# %%
print(classification_report(ytest,ypred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30

# %%
dtc.score(xtrain,ytrain), dtc.score(xtest,ytest)   # it is generalized model
# Out:
# (1.0, 0.9666666666666667)

# %% [markdown]
# # Regression

# %%
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
x = df.iloc[:,:3]
y = df['PetalWidthCm']

# %%
x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm
# Id
# 1              5.1           3.5            1.4
# 2              4.9           3.0            1.4
# 3              4.7           3.2            1.3
# 4              4.6           3.1            1.5
# 5              5.0           3.6            1.4
# ..             ...           ...            ...
# 146            6.7           3.0            5.2
# 147            6.3           2.5            5.0
# 148            6.5           3.0            5.2
# 149            6.2           3.4            5.4
# 150            5.9           3.0            5.1
#
# [150 rows x 3 columns]

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()

dtr.fit(xtrain,ytrain)
yp = dtr.predict(xtest)
yp
# Out:
# array([1.5, 0.4, 1.4, 1.4, 1.5, 0.2, 1. , 1.5, 1.7, 1.2, 1.7, 0.2, 0.2,
#        0.1, 0.4, 1.4, 1.8, 1.4, 1.5, 1.8, 0.2, 1.8, 0.2, 1.8, 2.2, 2.1,
#        1.4, 1.8, 0.2, 0.2, 0.3, 0.2, 1.4, 0.2, 0.2, 1.5, 1.4, 0.2, 0.3,
#        0.2, 1.9, 1.4, 1.3, 0.2, 0.2])

# %%
dtr.score(xtrain,ytrain), dtr.score(xtest,ytest)   # Overfitting Model
# Out:
# (0.998523988291134, 0.883761519128735)

# %%
#from sklearn.metrics import mean_squared_error   # MSE tells Amount of error

# %%
# MSE=mean_squared_error(ytest,yp)   #  As range of MSE 0 to + infinity perfomance of model is good
#print(MSE)
#import numpy as np
#RMSE=np.sqrt(mean_squared_error(ytest,yp))
#print(RMSE)

# %%
x.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm'], dtype='object')

# %%
tree.plot_tree(dtr, feature_names=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm'],max_depth=3, filled=True)
plt.show()

# %% [markdown]
# # Hyperparameter tuning

# %%
DecisionTreeRegressor()
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'criterion' : ['squared_error','absolute_error'],
    'max_depth' : [3,5,7,9,11],
    'splitter' :['best','random']
}

# %% [markdown]
# params = {
#     'criterion' : ['squared_error','absolute_error'],
#     'max_depth' : [3,5,7,9,11],
#     'splitter' :['best','random']
# }

# %%
grid = GridSearchCV(estimator=DecisionTreeRegressor(), param_grid=params,
                   verbose=1)          # verbose display posible combinations

# %%
grid.fit(xtrain,ytrain)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [3, 5, 7, 9, 11],
#                          'splitter': ['best', 'random']},
#              verbose=1)

# %%
grid.best_params_
# Out:
# {'criterion': 'squared_error', 'max_depth': 3, 'splitter': 'best'}

# %%
dtr = DecisionTreeRegressor(criterion='squared_error',
                           max_depth=3,splitter='best')

# %%
dtr.fit(xtrain,ytrain)
ypred  = dtr.predict(xtest)

# %%
dtr.score(xtrain,ytrain),dtr.score(xtest,ytest)  # Now it has become genralized model
# Out:
# (0.9419858001628175, 0.9327669485234616)

# %%
tree.plot_tree(dtr, feature_names=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm'],filled=True)
plt.show()
